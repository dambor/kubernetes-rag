# %%
# Install requirements
# !pip install "langchain>=0.2" "langchain-astradb>=0.4" \
    "langchain-openai>=0.1" "datasets>=3.0" "pypdf>=5.0" \
    "python-dotenv>=1.0"
# !pip install unstructured
# !pip install python-dotenv
# Out:
# Requirement already satisfied: langchain>=0.2 in /usr/local/lib/python3.10/dist-packages (0.3.11)
# Requirement already satisfied: langchain-astradb>=0.4 in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: langchain-openai>=0.1 in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: datasets>=3.0 in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: pypdf>=5.0 in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: python-dotenv>=1.0 in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (3.11.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (0.3.24)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (0.3.2)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (0.2.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.2) (9.0.0)
# Requirement already satisfied: astrapy<2.0.0,>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-astradb>=0.4) (1.5.2)
# Requirement already satisfied: langchain-community>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from langchain-astradb>=0.4) (0.3.11)
# Requirement already satisfied: openai<2.0.0,>=1.55.3 in /usr/local/lib/python3.10/dist-packages (from langchain-openai>=0.1) (1.57.4)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain-openai>=0.1) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (2.2.2)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=3.0) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (0.26.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=3.0) (24.2)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf>=5.0) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.2) (1.18.3)
# Requirement already satisfied: deprecation<2.2.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (0.28.1)
# Requirement already satisfied: pymongo>=3 in /usr/local/lib/python3.10/dist-packages (from astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (4.10.1)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (0.10.2)
# Requirement already satisfied: uuid6>=2024.1.12 in /usr/local/lib/python3.10/dist-packages (from astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (2024.7.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community>=0.3.1->langchain-astradb>=0.4) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community>=0.3.1->langchain-astradb>=0.4) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community>=0.3.1->langchain-astradb>=0.4) (2.7.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain>=0.2) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain>=0.2) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain>=0.2) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai>=0.1) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai>=0.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai>=0.1) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai>=0.1) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.2) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain>=0.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain>=0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain>=0.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain>=0.2) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain>=0.2) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai>=0.1) (2024.9.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=3.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=3.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=3.0) (2024.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai>=0.1) (1.2.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.1->langchain-astradb>=0.4) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.1->langchain-astradb>=0.4) (0.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (4.1.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain>=0.2) (3.0.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo>=3->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (2.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0) (1.17.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<2.0.0,>=1.5.2->langchain-astradb>=0.4) (4.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.1->langchain-astradb>=0.4) (1.0.0)
# Requirement already satisfied: unstructured in /usr/local/lib/python3.10/dist-packages (0.16.11)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.14.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured) (2024.10.22)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.10.1)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.28.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.9.5)
# Requirement already satisfied: python-oxmsg in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.0.1)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (2024.9.11)
# Requirement already satisfied: olefile in /usr/local/lib/python3.10/dist-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (43.0.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: pypdf>=4.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (5.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
from datasets import load_dataset

import os
import requests
from bs4 import BeautifulSoup
from getpass import getpass

from astrapy.db import AstraDB
import openai

from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.vectorstores import AstraDB as AstraVectorStore
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI

from langchain_astradb import AstraDBVectorStore
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings

# %%
import os
from dotenv import load_dotenv
from google.colab import drive

drive.mount('/content/drive')


env_file = "/content/drive/MyDrive/config/astra_config.env"

load_dotenv(env_file)

ASTRA_DB_APPLICATION_TOKEN = os.environ.get("ASTRA_DB_APPLICATION_TOKEN")
ASTRA_DB_API_ENDPOINT = os.environ.get("ASTRA_DB_API_ENDPOINT")
ASTRA_DB_KEYSPACE = os.environ.get("ASTRA_DB_KEYSPACE")
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
# Out:
# Mounted at /content/drive

# %%
# initiate astra db client
astra_db = AstraDB(
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
)

# %%
# create a collection
coll_name = "k8s_coll"
collection = astra_db.create_collection(coll_name, dimension=1536)

# %%
# scrape the documentation website
base_url = "https://kubernetes.io/docs/home/"
response = requests.get(base_url)
if response.status_code != 200:
    raise Exception("Failed to retrieve the base documentation page.")

soup = BeautifulSoup(response.text, "html.parser")

# %%
# This is a simple approach: find all <a> tags and keep those that lead to docs pages.
# You may need to refine this logic depending on the site's structure.
links = []
for a_tag in soup.find_all("a", href=True):
    href = a_tag['href']
    # Normalize and filter links
    # If href is relative, construct absolute URL
    if href.startswith("/"):
        full_url = base_url.rstrip("/") + href
    elif href.startswith(base_url):
        full_url = href
    else:
        # Skip external links
        continue

    # Basic filtering: skip fragments and duplicates
    if "#" in full_url:
        full_url = full_url.split("#")[0]

    if full_url not in links and full_url.startswith(base_url):
        links.append(full_url)

    print(full_url)
#links = ['http://docs.cast.ai']
print(f"Found {len(links)} potential links from the main page.")
print(links)
# Out:
# https://kubernetes.io/docs/home/
# https://kubernetes.io/docs/home/docs/
# https://kubernetes.io/docs/home/blog/
# https://kubernetes.io/docs/home/training/
# https://kubernetes.io/docs/home/partners/
# https://kubernetes.io/docs/home/community/
# https://kubernetes.io/docs/home/case-studies/
# https://kubernetes.io/docs/home/releases
# https://kubernetes.io/docs/home/
# https://kubernetes.io/docs/home/bn/docs/home/
# https://kubernetes.io/docs/home/zh-cn/docs/home/
# https://kubernetes.io/docs/home/fr/docs/home/
# https://kubernetes.io/docs/home/de/docs/home/
# https://kubernetes.io/docs/home/hi/docs/home/
# https://kubernetes.io/docs/home/id/docs/home/
# https://kubernetes.io/docs/home/it/docs/home/
# https://kubernetes.io/docs/home/ja/docs/home/
# https://kubernetes.io/docs/home/ko/docs/home/
# https://kubernetes.io/docs/home/pl/docs/home/
# https://kubernetes.io/docs/home/pt-br/docs/home/
# https://kubernetes.io/docs/home/ru/docs/home/
# https://kubernetes.io/docs/home/es/docs/home/
# https://kubernetes.io/docs/home/uk/docs/home/
# https://kubernetes.io/docs/home/vi/docs/home/
# https://kubernetes.io/docs/home/docs/home/
# https://kubernetes.io/docs/home/docs/home/supported-doc-versions/
# https://kubernetes.io/docs/home/docs/setup/
# https://kubernetes.io/docs/home/docs/setup/learning-environment/
# https://kubernetes.io/docs/home/docs/setup/production-environment/
# https://kubernetes.io/docs/home/docs/setup/production-environment/container-runtimes/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/install-kubeadm/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/troubleshooting-kubeadm/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/create-cluster-kubeadm/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/control-plane-flags/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/ha-topology/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/high-availability/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/setup-ha-etcd-with-kubeadm/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/kubelet-integration/
# https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/dual-stack-support/
# https://kubernetes.io/docs/home/docs/setup/production-environment/turnkey-solutions/
# https://kubernetes.io/docs/home/docs/setup/best-practices/
# https://kubernetes.io/docs/home/docs/setup/best-practices/cluster-large/
# https://kubernetes.io/docs/home/docs/setup/best-practices/multiple-zones/
# https://kubernetes.io/docs/home/docs/setup/best-practices/node-conformance/
# https://kubernetes.io/docs/home/docs/setup/best-practices/enforcing-pod-security-standards/
# https://kubernetes.io/docs/home/docs/setup/best-practices/certificates/
# https://kubernetes.io/docs/home/docs/concepts/
# https://kubernetes.io/docs/home/docs/concepts/overview/
# https://kubernetes.io/docs/home/docs/concepts/overview/components/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/object-management/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/names/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/labels/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/namespaces/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/annotations/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/field-selectors/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/finalizers/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/owners-dependents/
# https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/common-labels/
# https://kubernetes.io/docs/home/docs/concepts/overview/kubernetes-api/
# https://kubernetes.io/docs/home/docs/concepts/architecture/
# https://kubernetes.io/docs/home/docs/concepts/architecture/nodes/
# https://kubernetes.io/docs/home/docs/concepts/architecture/control-plane-node-communication/
# https://kubernetes.io/docs/home/docs/concepts/architecture/controller/
# https://kubernetes.io/docs/home/docs/concepts/architecture/leases/
# https://kubernetes.io/docs/home/docs/concepts/architecture/cloud-controller/
# https://kubernetes.io/docs/home/docs/concepts/architecture/cgroups/
# https://kubernetes.io/docs/home/docs/concepts/architecture/cri/
# https://kubernetes.io/docs/home/docs/concepts/architecture/garbage-collection/
# https://kubernetes.io/docs/home/docs/concepts/architecture/mixed-version-proxy/
# https://kubernetes.io/docs/home/docs/concepts/containers/
# https://kubernetes.io/docs/home/docs/concepts/containers/images/
# https://kubernetes.io/docs/home/docs/concepts/containers/container-environment/
# https://kubernetes.io/docs/home/docs/concepts/containers/runtime-class/
# https://kubernetes.io/docs/home/docs/concepts/containers/container-lifecycle-hooks/
# https://kubernetes.io/docs/home/docs/concepts/workloads/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/pod-lifecycle/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/init-containers/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/sidecar-containers/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/ephemeral-containers/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/disruptions/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/pod-qos/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/user-namespaces/
# https://kubernetes.io/docs/home/docs/concepts/workloads/pods/downward-api/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/deployment/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/replicaset/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/statefulset/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/daemonset/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/job/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/ttlafterfinished/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/cron-jobs/
# https://kubernetes.io/docs/home/docs/concepts/workloads/controllers/replicationcontroller/
# https://kubernetes.io/docs/home/docs/concepts/workloads/autoscaling/
# https://kubernetes.io/docs/home/docs/concepts/workloads/management/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/service/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/ingress/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/ingress-controllers/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/gateway/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/endpoint-slices/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/network-policies/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/dns-pod-service/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/dual-stack/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/topology-aware-routing/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/windows-networking/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/cluster-ip-allocation/
# https://kubernetes.io/docs/home/docs/concepts/services-networking/service-traffic-policy/
# https://kubernetes.io/docs/home/docs/concepts/storage/
# https://kubernetes.io/docs/home/docs/concepts/storage/volumes/
# https://kubernetes.io/docs/home/docs/concepts/storage/persistent-volumes/
# https://kubernetes.io/docs/home/docs/concepts/storage/projected-volumes/
# https://kubernetes.io/docs/home/docs/concepts/storage/ephemeral-volumes/
# https://kubernetes.io/docs/home/docs/concepts/storage/storage-classes/
# https://kubernetes.io/docs/home/docs/concepts/storage/volume-attributes-classes/
# https://kubernetes.io/docs/home/docs/concepts/storage/dynamic-provisioning/
# https://kubernetes.io/docs/home/docs/concepts/storage/volume-snapshots/
# https://kubernetes.io/docs/home/docs/concepts/storage/volume-snapshot-classes/
# https://kubernetes.io/docs/home/docs/concepts/storage/volume-pvc-datasource/
# https://kubernetes.io/docs/home/docs/concepts/storage/storage-capacity/
# https://kubernetes.io/docs/home/docs/concepts/storage/storage-limits/
# https://kubernetes.io/docs/home/docs/concepts/storage/volume-health-monitoring/
# https://kubernetes.io/docs/home/docs/concepts/storage/windows-storage/
# https://kubernetes.io/docs/home/docs/concepts/configuration/
# https://kubernetes.io/docs/home/docs/concepts/configuration/overview/
# https://kubernetes.io/docs/home/docs/concepts/configuration/configmap/
# https://kubernetes.io/docs/home/docs/concepts/configuration/secret/
# https://kubernetes.io/docs/home/docs/concepts/configuration/liveness-readiness-startup-probes/
# https://kubernetes.io/docs/home/docs/concepts/configuration/manage-resources-containers/
# https://kubernetes.io/docs/home/docs/concepts/configuration/organize-cluster-access-kubeconfig/
# https://kubernetes.io/docs/home/docs/concepts/configuration/windows-resource-management/
# https://kubernetes.io/docs/home/docs/concepts/security/
# https://kubernetes.io/docs/home/docs/concepts/security/cloud-native-security/
# https://kubernetes.io/docs/home/docs/concepts/security/pod-security-standards/
# https://kubernetes.io/docs/home/docs/concepts/security/pod-security-admission/
# https://kubernetes.io/docs/home/docs/concepts/security/service-accounts/
# https://kubernetes.io/docs/home/docs/concepts/security/pod-security-policy/
# https://kubernetes.io/docs/home/docs/concepts/security/windows-security/
# https://kubernetes.io/docs/home/docs/concepts/security/controlling-access/
# https://kubernetes.io/docs/home/docs/concepts/security/rbac-good-practices/
# https://kubernetes.io/docs/home/docs/concepts/security/secrets-good-practices/
# https://kubernetes.io/docs/home/docs/concepts/security/multi-tenancy/
# https://kubernetes.io/docs/home/docs/concepts/security/hardening-guide/authentication-mechanisms/
# https://kubernetes.io/docs/home/docs/concepts/security/api-server-bypass-risks/
# https://kubernetes.io/docs/home/docs/concepts/security/linux-kernel-security-constraints/
# https://kubernetes.io/docs/home/docs/concepts/security/security-checklist/
# https://kubernetes.io/docs/home/docs/concepts/security/application-security-checklist/
# https://kubernetes.io/docs/home/docs/concepts/policy/
# https://kubernetes.io/docs/home/docs/concepts/policy/limit-range/
# https://kubernetes.io/docs/home/docs/concepts/policy/resource-quotas/
# https://kubernetes.io/docs/home/docs/concepts/policy/pid-limiting/
# https://kubernetes.io/docs/home/docs/concepts/policy/node-resource-managers/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/kube-scheduler/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/assign-pod-node/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/pod-overhead/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/pod-scheduling-readiness/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/topology-spread-constraints/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/taint-and-toleration/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/scheduling-framework/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/dynamic-resource-allocation/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/scheduler-perf-tuning/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/resource-bin-packing/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/pod-priority-preemption/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/node-pressure-eviction/
# https://kubernetes.io/docs/home/docs/concepts/scheduling-eviction/api-eviction/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/node-shutdown/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/certificates/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/networking/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/logging/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/compatibility-version/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/system-metrics/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/kube-state-metrics/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/system-logs/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/system-traces/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/proxies/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/flow-control/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/cluster-autoscaling/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/addons/
# https://kubernetes.io/docs/home/docs/concepts/cluster-administration/coordinated-leader-election/
# https://kubernetes.io/docs/home/docs/concepts/windows/
# https://kubernetes.io/docs/home/docs/concepts/windows/intro/
# https://kubernetes.io/docs/home/docs/concepts/windows/user-guide/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/compute-storage-net/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/compute-storage-net/network-plugins/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/compute-storage-net/device-plugins/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/api-extension/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/api-extension/custom-resources/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/api-extension/apiserver-aggregation/
# https://kubernetes.io/docs/home/docs/concepts/extend-kubernetes/operator/
# https://kubernetes.io/docs/home/docs/tasks/
# https://kubernetes.io/docs/home/docs/tasks/tools/
# https://kubernetes.io/docs/home/docs/tasks/tools/install-kubectl-linux/
# https://kubernetes.io/docs/home/docs/tasks/tools/install-kubectl-macos/
# https://kubernetes.io/docs/home/docs/tasks/tools/install-kubectl-windows/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/adding-linux-nodes/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/adding-windows-nodes/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/kubeadm-upgrade/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/upgrading-linux-nodes/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/upgrading-windows-nodes/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/configure-cgroup-driver/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/kubeadm-certs/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/kubeadm-reconfigure/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubeadm/change-package-repository/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/node-overprovisioning/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/change-runtime-containerd/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/migrate-dockershim-dockerd/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/find-out-runtime-you-use/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/troubleshooting-cni-plugin-related-errors/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/check-if-dockershim-removal-affects-you/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/migrating-from-dockershim/migrating-telemetry-and-security-agents/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/certificates/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/memory-default-namespace/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/cpu-default-namespace/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/memory-constraint-namespace/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/cpu-constraint-namespace/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/quota-memory-cpu-namespace/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/manage-resources/quota-pod-namespace/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/antrea-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/calico-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/cilium-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/kube-router-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/romana-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/network-policy-provider/weave-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/access-cluster-api/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/extended-resource-node/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/dns-horizontal-autoscaling/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/change-pv-access-mode-readwriteoncepod/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/change-default-storage-class/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/switch-to-evented-pleg/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/change-pv-reclaim-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/running-cloud-controller/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubelet-credential-provider/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/quota-api-object/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/cpu-management-policies/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/topology-manager/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/dns-custom-nameservers/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/dns-debugging-resolution/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/declare-network-policy/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/developing-cloud-controller-manager/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/enable-disable-api/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/encrypt-data/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/decrypt-data/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/guaranteed-scheduling-critical-addon-pods/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/ip-masq-agent/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/limit-storage-consumption/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/controller-manager-leader-migration/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/namespaces-walkthrough/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/configure-upgrade-etcd/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/reserve-compute-resources/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubelet-in-userns/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/safely-drain-node/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/securing-a-cluster/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kubelet-config-file/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/namespaces/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/cluster-upgrade/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/use-cascading-deletion/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/kms-provider/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/coredns/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/nodelocaldns/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/sysctl-cluster/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/memory-manager/
# https://kubernetes.io/docs/home/docs/tasks/administer-cluster/verify-signed-artifacts/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/assign-memory-resource/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/assign-cpu-resource/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/assign-pod-level-resources/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-gmsa/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/resize-container-resources/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-runasusername/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/create-hostprocess-pod/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/quality-service-pod/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/extended-resource/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-volume-storage/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-persistent-volume-storage/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-projected-volume-storage/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/security-context/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-service-account/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/pull-image-private-registry/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-liveness-readiness-startup-probes/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/assign-pods-nodes/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/assign-pods-nodes-using-node-affinity/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-pod-initialization/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/attach-handler-lifecycle-event/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/configure-pod-configmap/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/share-process-namespace/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/user-namespaces/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/image-volumes/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/static-pod/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/translate-compose-kubernetes/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/enforce-standards-admission-controller/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/enforce-standards-namespace-labels/
# https://kubernetes.io/docs/home/docs/tasks/configure-pod-container/migrate-from-psp/
# https://kubernetes.io/docs/home/docs/tasks/debug/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/debug-pods/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/debug-service/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/debug-statefulset/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/determine-reason-pod-failure/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/debug-init-containers/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/debug-running-pod/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-application/get-shell-running-container/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/troubleshoot-kubectl/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/resource-metrics-pipeline/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/resource-usage-monitoring/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/monitor-node-health/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/crictl/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/audit/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/kubectl-node-debug/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/local-debugging/
# https://kubernetes.io/docs/home/docs/tasks/debug/debug-cluster/windows/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/declarative-config/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/kustomization/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/imperative-command/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/imperative-config/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/update-api-object-kubectl-patch/
# https://kubernetes.io/docs/home/docs/tasks/manage-kubernetes-objects/storage-version-migration/
# https://kubernetes.io/docs/home/docs/tasks/configmap-secret/
# https://kubernetes.io/docs/home/docs/tasks/configmap-secret/managing-secret-using-kubectl/
# https://kubernetes.io/docs/home/docs/tasks/configmap-secret/managing-secret-using-config-file/
# https://kubernetes.io/docs/home/docs/tasks/configmap-secret/managing-secret-using-kustomize/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/define-command-argument-container/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/define-interdependent-environment-variables/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/define-environment-variable-container/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/environment-variable-expose-pod-information/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/downward-api-volume-expose-pod-information/
# https://kubernetes.io/docs/home/docs/tasks/inject-data-application/distribute-credentials-secure/
# https://kubernetes.io/docs/home/docs/tasks/run-application/
# https://kubernetes.io/docs/home/docs/tasks/run-application/run-stateless-application-deployment/
# https://kubernetes.io/docs/home/docs/tasks/run-application/run-single-instance-stateful-application/
# https://kubernetes.io/docs/home/docs/tasks/run-application/run-replicated-stateful-application/
# https://kubernetes.io/docs/home/docs/tasks/run-application/scale-stateful-set/
# https://kubernetes.io/docs/home/docs/tasks/run-application/delete-stateful-set/
# https://kubernetes.io/docs/home/docs/tasks/run-application/force-delete-stateful-set-pod/
# https://kubernetes.io/docs/home/docs/tasks/run-application/horizontal-pod-autoscale/
# https://kubernetes.io/docs/home/docs/tasks/run-application/horizontal-pod-autoscale-walkthrough/
# https://kubernetes.io/docs/home/docs/tasks/run-application/configure-pdb/
# https://kubernetes.io/docs/home/docs/tasks/run-application/access-api-from-pod/
# https://kubernetes.io/docs/home/docs/tasks/job/
# https://kubernetes.io/docs/home/docs/tasks/job/automated-tasks-with-cron-jobs/
# https://kubernetes.io/docs/home/docs/tasks/job/coarse-parallel-processing-work-queue/
# https://kubernetes.io/docs/home/docs/tasks/job/fine-parallel-processing-work-queue/
# https://kubernetes.io/docs/home/docs/tasks/job/indexed-parallel-processing-static/
# https://kubernetes.io/docs/home/docs/tasks/job/job-with-pod-to-pod-communication/
# https://kubernetes.io/docs/home/docs/tasks/job/parallel-processing-expansion/
# https://kubernetes.io/docs/home/docs/tasks/job/pod-failure-policy/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/web-ui-dashboard/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/access-cluster/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/configure-access-multiple-clusters/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/port-forward-access-application-cluster/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/service-access-application-cluster/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/connecting-frontend-backend/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/create-external-load-balancer/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/list-all-running-container-images/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/ingress-minikube/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/communicate-containers-same-pod-shared-volume/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/configure-dns-cluster/
# https://kubernetes.io/docs/home/docs/tasks/access-application-cluster/access-cluster-services/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/configure-aggregation-layer/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/custom-resources/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/custom-resources/custom-resource-definitions/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/custom-resources/custom-resource-definition-versioning/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/setup-extension-api-server/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/configure-multiple-schedulers/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/http-proxy-access-api/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/socks5-proxy-access-api/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubernetes/setup-konnectivity/
# https://kubernetes.io/docs/home/docs/tasks/tls/
# https://kubernetes.io/docs/home/docs/tasks/tls/certificate-rotation/
# https://kubernetes.io/docs/home/docs/tasks/tls/managing-tls-in-a-cluster/
# https://kubernetes.io/docs/home/docs/tasks/tls/manual-rotation-of-ca-certificates/
# https://kubernetes.io/docs/home/docs/tasks/manage-daemon/
# https://kubernetes.io/docs/home/docs/tasks/manage-daemon/update-daemon-set/
# https://kubernetes.io/docs/home/docs/tasks/manage-daemon/rollback-daemon-set/
# https://kubernetes.io/docs/home/docs/tasks/manage-daemon/pods-some-nodes/
# https://kubernetes.io/docs/home/docs/tasks/network/
# https://kubernetes.io/docs/home/docs/tasks/network/customize-hosts-file-for-pods/
# https://kubernetes.io/docs/home/docs/tasks/network/extend-service-ip-ranges/
# https://kubernetes.io/docs/home/docs/tasks/network/validate-dual-stack/
# https://kubernetes.io/docs/home/docs/tasks/extend-kubectl/kubectl-plugins/
# https://kubernetes.io/docs/home/docs/tasks/manage-hugepages/scheduling-hugepages/
# https://kubernetes.io/docs/home/docs/tasks/manage-gpus/scheduling-gpus/
# https://kubernetes.io/docs/home/docs/tutorials/
# https://kubernetes.io/docs/home/docs/tutorials/hello-minikube/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/create-cluster/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/create-cluster/cluster-intro/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/deploy-app/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/deploy-app/deploy-intro/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/explore/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/explore/explore-intro/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/expose/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/expose/expose-intro/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/scale/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/scale/scale-intro/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/update/
# https://kubernetes.io/docs/home/docs/tutorials/kubernetes-basics/update/update-intro/
# https://kubernetes.io/docs/home/docs/tutorials/configuration/
# https://kubernetes.io/docs/home/docs/tutorials/configuration/updating-configuration-via-a-configmap/
# https://kubernetes.io/docs/home/docs/tutorials/configuration/configure-redis-using-configmap/
# https://kubernetes.io/docs/home/docs/tutorials/configuration/pod-sidecar-containers/
# https://kubernetes.io/docs/home/docs/tutorials/security/
# https://kubernetes.io/docs/home/docs/tutorials/security/cluster-level-pss/
# https://kubernetes.io/docs/home/docs/tutorials/security/ns-level-pss/
# https://kubernetes.io/docs/home/docs/tutorials/security/apparmor/
# https://kubernetes.io/docs/home/docs/tutorials/security/seccomp/
# https://kubernetes.io/docs/home/docs/tutorials/stateless-application/
# https://kubernetes.io/docs/home/docs/tutorials/stateless-application/expose-external-ip-address/
# https://kubernetes.io/docs/home/docs/tutorials/stateless-application/guestbook/
# https://kubernetes.io/docs/home/docs/tutorials/stateful-application/
# https://kubernetes.io/docs/home/docs/tutorials/stateful-application/basic-stateful-set/
# https://kubernetes.io/docs/home/docs/tutorials/stateful-application/mysql-wordpress-persistent-volume/
# https://kubernetes.io/docs/home/docs/tutorials/stateful-application/cassandra/
# https://kubernetes.io/docs/home/docs/tutorials/stateful-application/zookeeper/
# https://kubernetes.io/docs/home/docs/tutorials/cluster-management/
# https://kubernetes.io/docs/home/docs/tutorials/cluster-management/kubelet-standalone/
# https://kubernetes.io/docs/home/docs/tutorials/services/
# https://kubernetes.io/docs/home/docs/tutorials/services/connect-applications-service/
# https://kubernetes.io/docs/home/docs/tutorials/services/source-ip/
# https://kubernetes.io/docs/home/docs/tutorials/services/pods-and-endpoint-termination-flow/
# https://kubernetes.io/docs/home/docs/reference/
# https://kubernetes.io/docs/home/docs/reference/glossary/
# https://kubernetes.io/docs/home/docs/reference/using-api/
# https://kubernetes.io/docs/home/docs/reference/using-api/api-concepts/
# https://kubernetes.io/docs/home/docs/reference/using-api/server-side-apply/
# https://kubernetes.io/docs/home/docs/reference/using-api/client-libraries/
# https://kubernetes.io/docs/home/docs/reference/using-api/cel/
# https://kubernetes.io/docs/home/docs/reference/using-api/deprecation-policy/
# https://kubernetes.io/docs/home/docs/reference/using-api/deprecation-guide/
# https://kubernetes.io/docs/home/docs/reference/using-api/health-checks/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/authentication/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/bootstrap-tokens/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/authorization/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/rbac/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/node/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/webhook/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/abac/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/admission-controllers/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/extensible-admission-controllers/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/service-accounts-admin/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/certificate-signing-requests/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/psp-to-pod-security-standards/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/kubelet-authn-authz/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/kubelet-tls-bootstrapping/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/mutating-admission-policy/
# https://kubernetes.io/docs/home/docs/reference/access-authn-authz/validating-admission-policy/
# https://kubernetes.io/docs/home/docs/reference/labels-annotations-taints/
# https://kubernetes.io/docs/home/docs/reference/labels-annotations-taints/audit-annotations/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/pod-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/binding-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/pod-template-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/replication-controller-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/replica-set-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/deployment-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/stateful-set-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/controller-revision-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/daemon-set-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/job-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/cron-job-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/horizontal-pod-autoscaler-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/horizontal-pod-autoscaler-v2/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/priority-class-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/pod-scheduling-context-v1alpha3/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/resource-claim-v1alpha3/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/resource-claim-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/resource-claim-template-v1alpha3/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/resource-claim-template-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/resource-slice-v1alpha3/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/workload-resources/resource-slice-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/service-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/service-resources/service-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/service-resources/endpoints-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/service-resources/endpoint-slice-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/service-resources/ingress-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/service-resources/ingress-class-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/config-map-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/secret-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/csi-driver-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/csi-node-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/csi-storage-capacity-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/persistent-volume-claim-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/persistent-volume-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/storage-class-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/storage-version-migration-v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/volume/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/volume-attachment-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/config-and-storage-resources/volume-attributes-class-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/service-account-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/token-request-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/token-review-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/certificate-signing-request-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/cluster-trust-bundle-v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authentication-resources/self-subject-review-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/local-subject-access-review-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/self-subject-access-review-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/self-subject-rules-review-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/subject-access-review-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/cluster-role-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/cluster-role-binding-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/role-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/authorization-resources/role-binding-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/flow-schema-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/limit-range-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/resource-quota-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/network-policy-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/pod-disruption-budget-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/priority-level-configuration-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/validating-admission-policy-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/policy-resources/validating-admission-policy-binding-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/extend-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/extend-resources/custom-resource-definition-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/extend-resources/device-class-v1alpha3/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/extend-resources/device-class-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/extend-resources/mutating-webhook-configuration-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/extend-resources/validating-webhook-configuration-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/api-service-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/component-status-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/event-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/ip-address-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/lease-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/lease-candidate-v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/namespace-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/node-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/runtime-class-v1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/cluster-resources/service-cidr-v1beta1/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/delete-options/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/label-selector/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/list-meta/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/local-object-reference/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/node-selector-requirement/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/object-field-selector/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/object-meta/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/object-reference/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/patch/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/quantity/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/resource-field-selector/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/status/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-definitions/typed-local-object-reference/
# https://kubernetes.io/docs/home/docs/reference/kubernetes-api/common-parameters/common-parameters/
# https://kubernetes.io/docs/home/docs/reference/instrumentation/
# https://kubernetes.io/docs/home/docs/reference/instrumentation/slis/
# https://kubernetes.io/docs/home/docs/reference/instrumentation/cri-pod-container-metrics/
# https://kubernetes.io/docs/home/docs/reference/instrumentation/node-metrics/
# https://kubernetes.io/docs/home/docs/reference/instrumentation/zpages/
# https://kubernetes.io/docs/home/docs/reference/instrumentation/metrics/
# ...
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_deployment/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_ingress/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_job/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_namespace/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_poddisruptionbudget/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_priorityclass/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_quota/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_role/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_rolebinding/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_secret/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_secret_docker-registry/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_secret_generic/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_secret_tls/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_service/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_service_clusterip/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_service_externalname/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_service_loadbalancer/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_service_nodeport/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_serviceaccount/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_create/kubectl_create_token/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_debug/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_delete/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_describe/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_diff/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_drain/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_edit/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_events/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_exec/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_explain/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_expose/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_get/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_kustomize/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_label/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_logs/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_options/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_patch/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_plugin/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_plugin/kubectl_plugin_list/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_port-forward/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_proxy/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_replace/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/kubectl_rollout_history/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/kubectl_rollout_pause/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/kubectl_rollout_restart/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/kubectl_rollout_resume/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/kubectl_rollout_status/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_rollout/kubectl_rollout_undo/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_run/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_scale/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/kubectl_set_env/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/kubectl_set_image/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/kubectl_set_resources/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/kubectl_set_selector/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/kubectl_set_serviceaccount/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_set/kubectl_set_subject/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_taint/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_top/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_top/kubectl_top_node/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_top/kubectl_top_pod/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_uncordon/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_version/
# https://kubernetes.io/docs/home/docs/reference/kubectl/generated/kubectl_wait/
# https://kubernetes.io/docs/home/docs/reference/kubectl/kubectl-cmds/
# https://kubernetes.io/docs/home/docs/reference/kubectl/kubectl/
# https://kubernetes.io/docs/home/docs/reference/kubectl/jsonpath/
# https://kubernetes.io/docs/home/docs/reference/kubectl/docker-cli-to-kubectl/
# https://kubernetes.io/docs/home/docs/reference/kubectl/conventions/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/feature-gates/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/feature-gates-removed/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/kubelet/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/kube-apiserver/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/kube-controller-manager/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/kube-proxy/
# https://kubernetes.io/docs/home/docs/reference/command-line-tools-reference/kube-scheduler/
# https://kubernetes.io/docs/home/docs/reference/debug-cluster/
# https://kubernetes.io/docs/home/docs/reference/debug-cluster/flow-control/
# https://kubernetes.io/docs/home/docs/reference/config-api/
# https://kubernetes.io/docs/home/docs/reference/config-api/client-authentication.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/client-authentication.v1beta1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-eventratelimit.v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/config-api/imagepolicy.v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-admission.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-audit.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-config.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-config.v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-config.v1beta1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kube-controller-manager-config.v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kube-proxy-config.v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kube-scheduler-config.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubeadm-config.v1beta3/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubeadm-config.v1beta4/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubeconfig.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubelet-config.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubelet-config.v1alpha1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubelet-config.v1beta1/
# https://kubernetes.io/docs/home/docs/reference/config-api/kubelet-credentialprovider.v1/
# https://kubernetes.io/docs/home/docs/reference/config-api/apiserver-webhookadmission.v1/
# https://kubernetes.io/docs/home/docs/reference/external-api/
# https://kubernetes.io/docs/home/docs/reference/external-api/custom-metrics.v1beta2/
# https://kubernetes.io/docs/home/docs/reference/external-api/external-metrics.v1beta1/
# https://kubernetes.io/docs/home/docs/reference/external-api/metrics.v1beta1/
# https://kubernetes.io/docs/home/docs/reference/scheduling/
# https://kubernetes.io/docs/home/docs/reference/scheduling/config/
# https://kubernetes.io/docs/home/docs/reference/scheduling/policies/
# https://kubernetes.io/docs/home/docs/reference/tools/
# https://kubernetes.io/docs/home/docs/contribute/
# https://kubernetes.io/docs/home/docs/contribute/docs/
# https://kubernetes.io/docs/home/docs/contribute/suggesting-improvements/
# https://kubernetes.io/docs/home/docs/contribute/new-content/
# https://kubernetes.io/docs/home/docs/contribute/new-content/open-a-pr/
# https://kubernetes.io/docs/home/docs/contribute/new-content/new-features/
# https://kubernetes.io/docs/home/docs/contribute/new-content/blogs-case-studies/
# https://kubernetes.io/docs/home/docs/contribute/review/
# https://kubernetes.io/docs/home/docs/contribute/review/reviewing-prs/
# https://kubernetes.io/docs/home/docs/contribute/review/for-approvers/
# https://kubernetes.io/docs/home/docs/contribute/localization/
# https://kubernetes.io/docs/home/docs/contribute/participate/
# https://kubernetes.io/docs/home/docs/contribute/participate/roles-and-responsibilities/
# https://kubernetes.io/docs/home/docs/contribute/participate/issue-wrangler/
# https://kubernetes.io/docs/home/docs/contribute/participate/pr-wranglers/
# https://kubernetes.io/docs/home/docs/contribute/style/
# https://kubernetes.io/docs/home/docs/contribute/style/content-guide/
# https://kubernetes.io/docs/home/docs/contribute/style/style-guide/
# https://kubernetes.io/docs/home/docs/contribute/style/diagram-guide/
# https://kubernetes.io/docs/home/docs/contribute/style/write-new-topic/
# https://kubernetes.io/docs/home/docs/contribute/style/page-content-types/
# https://kubernetes.io/docs/home/docs/contribute/style/content-organization/
# https://kubernetes.io/docs/home/docs/contribute/style/hugo-shortcodes/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/quickstart/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/contribute-upstream/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/kubernetes-api/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/kubectl/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/metrics-reference/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/kubernetes-components/
# https://kubernetes.io/docs/home/docs/contribute/generate-ref-docs/prerequisites-ref-docs/
# https://kubernetes.io/docs/home/docs/contribute/advanced/
# https://kubernetes.io/docs/home/docs/contribute/analytics/
# https://kubernetes.io/docs/home/docs/test/
# https://kubernetes.io/docs/home/_print/
# Found 794 potential links from the main page.
# ['https://kubernetes.io/docs/home/', 'https://kubernetes.io/docs/home/docs/', 'https://kubernetes.io/docs/home/blog/', 'https://kubernetes.io/docs/home/training/', 'https://kubernetes.io/docs/home/partners/', 'https://kubernetes.io/docs/home/community/', 'https://kubernetes.io/docs/home/case-studies/', 'https://kubernetes.io/docs/home/releases', 'https://kubernetes.io/docs/home/bn/docs/home/', 'https://kubernetes.io/docs/home/zh-cn/docs/home/', 'https://kubernetes.io/docs/home/fr/docs/home/', 'https://kubernetes.io/docs/home/de/docs/home/', 'https://kubernetes.io/docs/home/hi/docs/home/', 'https://kubernetes.io/docs/home/id/docs/home/', 'https://kubernetes.io/docs/home/it/docs/home/', 'https://kubernetes.io/docs/home/ja/docs/home/', 'https://kubernetes.io/docs/home/ko/docs/home/', 'https://kubernetes.io/docs/home/pl/docs/home/', 'https://kubernetes.io/docs/home/pt-br/docs/home/', 'https://kubernetes.io/docs/home/ru/docs/home/', 'https://kubernetes.io/docs/home/es/docs/home/', 'https://kubernetes.io/docs/home/uk/docs/home/', 'https://kubernetes.io/docs/home/vi/docs/home/', 'https://kubernetes.io/docs/home/docs/home/', 'https://kubernetes.io/docs/home/docs/home/supported-doc-versions/', 'https://kubernetes.io/docs/home/docs/setup/', 'https://kubernetes.io/docs/home/docs/setup/learning-environment/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/container-runtimes/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/install-kubeadm/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/troubleshooting-kubeadm/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/create-cluster-kubeadm/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/control-plane-flags/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/ha-topology/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/high-availability/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/setup-ha-etcd-with-kubeadm/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/kubelet-integration/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/tools/kubeadm/dual-stack-support/', 'https://kubernetes.io/docs/home/docs/setup/production-environment/turnkey-solutions/', 'https://kubernetes.io/docs/home/docs/setup/best-practices/', 'https://kubernetes.io/docs/home/docs/setup/best-practices/cluster-large/', 'https://kubernetes.io/docs/home/docs/setup/best-practices/multiple-zones/', 'https://kubernetes.io/docs/home/docs/setup/best-practices/node-conformance/', 'https://kubernetes.io/docs/home/docs/setup/best-practices/enforcing-pod-security-standards/', 'https://kubernetes.io/docs/home/docs/setup/best-practices/certificates/', 'https://kubernetes.io/docs/home/docs/concepts/', 'https://kubernetes.io/docs/home/docs/concepts/overview/', 'https://kubernetes.io/docs/home/docs/concepts/overview/components/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/object-management/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/names/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/labels/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/namespaces/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/annotations/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-with-objects/field-selectors/', 'https://kubernetes.io/docs/home/docs/concepts/overview/working-wi ...

# %%
# ====== Load Documents from Extracted URLs ======
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
from langchain.document_loaders import UnstructuredURLLoader

loader = UnstructuredURLLoader(urls=links)
docs = loader.load()

print(f"Number of documents loaded: {len(docs)}")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Number of documents loaded: 794

# %%
# split documents
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
docs_split = text_splitter.split_documents(docs)
print(f"Number of chunks: {len(docs_split)}")
# Out:
# Number of chunks: 796

# %%
embedding = OpenAIEmbeddings()

vectorstore = AstraVectorStore.from_documents(
    documents=docs_split,
    embedding=embedding,
    token=ASTRA_DB_APPLICATION_TOKEN,
    astra_client=astra_db,
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    keyspace=ASTRA_DB_KEYSPACE,
    collection_name=coll_name,
)

retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k":3})

llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, temperature=0)
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/astradb.py:1167: UserWarning: Method 'from_texts' of AstraDB vector store invoked with unsupported arguments (astra_client, keyspace), which will be ignored.
#   warnings.warn(

# %%
# define a safe query function
def ask_question(query: str):
    response = qa_chain({"query": query})
    if not response["source_documents"]:
        return "answer not found"
    if not response["result"].strip():
        return "answer not found"
    return response["result"]

# %%
# example usage
user_query = input("What would you like to ask about CAST AI?")
answer = qa_chain.invoke({"query": user_query})

print(answer['result'])
# Out:
# What would you like to ask about CAST AI?how to configure node affinity
# To configure node affinity in Kubernetes, you can use the following steps:
#
# 1. Define a node selector for your pod by adding the `nodeSelector` field to your pod specification. This field specifies a map of key-value pairs that must match the labels on a node for the pod to be scheduled on that node.
#
# 2. Use the `kubectl label nodes` command to add labels to your nodes. For example, you can label a node with `kubectl label nodes <node-name> <label-key>=<label-value>`.
#
# 3. Update your pod specification to include the node selector that matches the labels you set on your nodes. For example:
#    ```yaml
#    spec:
#      nodeSelector:
#        <label-key>: <label-value>
#    ```
#
# 4. Apply the updated pod specification using `kubectl apply -f <pod-spec-file.yaml>`.
#
# By following these steps, you can configure node affinity for your pods in Kubernetes.
